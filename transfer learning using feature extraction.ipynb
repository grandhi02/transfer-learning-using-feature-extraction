# %%
import os

# initialize the path to the *original* input directory of images
ORIG_INPUT_DATASET = "Food-5K"

# initialize the base path to the *new* directory that will contain
# our images after computing the training and testing split
BASE_PATH = "dataset"

# define the names of the training, testing, and validation
# directories
TRAIN = "training"
TEST = "evaluation"
VAL = "validation"

# initialize the list of class label names
CLASSES = ["non_food", "food"]

# set the batch size
BATCH_SIZE = 32

# initialize the label encoder file path and the output directory to
# where the extracted features (in CSV file format) will be stored
LE_PATH = os.path.sep.join(["output", "le.cpickle"])
BASE_CSV_PATH = "output"

# set the path to the serialized model after training
MODEL_PATH = os.path.sep.join(["output", "model.cpickle"])

# %%
# import the necessary packages
#pyt is a floder consisting config file
from pyt import config
from imutils import paths
import shutil
import os

# loop over the data splits
for split in (config.TRAIN, config.TEST, config.VAL):
    # grab all image paths in the current split
    print("[INFO] processing '{} split'...".format(split))
    p = os.path.sep.join([config.ORIG_INPUT_DATASET, split])
    print(p)
    print("-----------------------------------------")
    print(os.path.sep)
    imagePaths = list(paths.list_images(p))
    print(imagePaths)


    # loop over the image paths
    for imagePath in imagePaths:
        # extract class label from the filename
        print(imagePath.split(os.path.sep)[-1])
        filename = imagePath.split(os.path.sep)[-1]
        label = config.CLASSES[int(filename.split("_")[0])]
        print(label)

        # construct the path to the output directory
        dirPath = os.path.sep.join([config.BASE_PATH, split, label])
        
        print(dirPath)

        # if the output directory does not exist, create it
        if not os.path.exists(dirPath):
            print("yessssssssssssSssssssssssssssss")
            os.makedirs(dirPath)
#construct the path to the output image file and copy it
        print("hi")
        p = os.path.sep.join([dirPath, filename])
        shutil.copy2(imagePath, p)
# Out:
# [INFO] processing 'training split'...
# Food-5K\training
# -----------------------------------------
# \
# ['Food-5K\\training\\0_0.jpg', 'Food-5K\\training\\0_1.jpg', 'Food-5K\\training\\0_10.jpg', 'Food-5K\\training\\0_100.jpg', 'Food-5K\\training\\0_1000.jpg', 'Food-5K\\training\\0_1001.jpg', 'Food-5K\\training\\0_1002.jpg', 'Food-5K\\training\\0_1003.jpg', 'Food-5K\\training\\0_1004.jpg', 'Food-5K\\training\\0_1005.jpg', 'Food-5K\\training\\0_1006.jpg', 'Food-5K\\training\\0_1007.jpg', 'Food-5K\\training\\0_1008.jpg', 'Food-5K\\training\\0_1009.jpg', 'Food-5K\\training\\0_101.jpg', 'Food-5K\\training\\0_1010.jpg', 'Food-5K\\training\\0_1011.jpg', 'Food-5K\\training\\0_1012.jpg', 'Food-5K\\training\\0_1013.jpg', 'Food-5K\\training\\0_1014.jpg', 'Food-5K\\training\\0_1015.jpg', 'Food-5K\\training\\0_1016.jpg', 'Food-5K\\training\\0_1017.jpg', 'Food-5K\\training\\0_1018.jpg', 'Food-5K\\training\\0_1019.jpg', 'Food-5K\\training\\0_102.jpg', 'Food-5K\\training\\0_1020.jpg', 'Food-5K\\training\\0_1021.jpg', 'Food-5K\\training\\0_1022.jpg', 'Food-5K\\training\\0_1023.jpg', 'Food-5K\\training\\0_1024.jpg', 'Food-5K\\training\\0_1025.jpg', 'Food-5K\\training\\0_1026.jpg', 'Food-5K\\training\\0_1027.jpg', 'Food-5K\\training\\0_1028.jpg', 'Food-5K\\training\\0_1029.jpg', 'Food-5K\\training\\0_103.jpg', 'Food-5K\\training\\0_1030.jpg', 'Food-5K\\training\\0_1031.jpg', 'Food-5K\\training\\0_1032.jpg', 'Food-5K\\training\\0_1033.jpg', 'Food-5K\\training\\0_1034.jpg', 'Food-5K\\training\\0_1035.jpg', 'Food-5K\\training\\0_1036.jpg', 'Food-5K\\training\\0_1037.jpg', 'Food-5K\\training\\0_1038.jpg', 'Food-5K\\training\\0_1039.jpg', 'Food-5K\\training\\0_104.jpg', 'Food-5K\\training\\0_1040.jpg', 'Food-5K\\training\\0_1041.jpg', 'Food-5K\\training\\0_1042.jpg', 'Food-5K\\training\\0_1043.jpg', 'Food-5K\\training\\0_1044.jpg', 'Food-5K\\training\\0_1045.jpg', 'Food-5K\\training\\0_1046.jpg', 'Food-5K\\training\\0_1047.jpg', 'Food-5K\\training\\0_1048.jpg', 'Food-5K\\training\\0_1049.jpg', 'Food-5K\\training\\0_105.jpg', 'Food-5K\\training\\0_1050.jpg', 'Food-5K\\training\\0_1051.jpg', 'Food-5K\\training\\0_1052.jpg', 'Food-5K\\training\\0_1053.jpg', 'Food-5K\\training\\0_1054.jpg', 'Food-5K\\training\\0_1055.jpg', 'Food-5K\\training\\0_1056.jpg', 'Food-5K\\training\\0_1057.jpg', 'Food-5K\\training\\0_1058.jpg', 'Food-5K\\training\\0_1059.jpg', 'Food-5K\\training\\0_106.jpg', 'Food-5K\\training\\0_1060.jpg', 'Food-5K\\training\\0_1061.jpg', 'Food-5K\\training\\0_1062.jpg', 'Food-5K\\training\\0_1063.jpg', 'Food-5K\\training\\0_1064.jpg', 'Food-5K\\training\\0_1065.jpg', 'Food-5K\\training\\0_1066.jpg', 'Food-5K\\training\\0_1067.jpg', 'Food-5K\\training\\0_1068.jpg', 'Food-5K\\training\\0_1069.jpg', 'Food-5K\\training\\0_107.jpg', 'Food-5K\\training\\0_1070.jpg', 'Food-5K\\training\\0_1071.jpg', 'Food-5K\\training\\0_1072.jpg', 'Food-5K\\training\\0_1073.jpg', 'Food-5K\\training\\0_1074.jpg', 'Food-5K\\training\\0_1075.jpg', 'Food-5K\\training\\0_1076.jpg', 'Food-5K\\training\\0_1077.jpg', 'Food-5K\\training\\0_1078.jpg', 'Food-5K\\training\\0_1079.jpg', 'Food-5K\\training\\0_108.jpg', 'Food-5K\\training\\0_1080.jpg', 'Food-5K\\training\\0_1081.jpg', 'Food-5K\\training\\0_1082.jpg', 'Food-5K\\training\\0_1083.jpg', 'Food-5K\\training\\0_1084.jpg', 'Food-5K\\training\\0_1085.jpg', 'Food-5K\\training\\0_1086.jpg', 'Food-5K\\training\\0_1087.jpg', 'Food-5K\\training\\0_1088.jpg', 'Food-5K\\training\\0_1089.jpg', 'Food-5K\\training\\0_109.jpg', 'Food-5K\\training\\0_1090.jpg', 'Food-5K\\training\\0_1091.jpg', 'Food-5K\\training\\0_1092.jpg', 'Food-5K\\training\\0_1093.jpg', 'Food-5K\\training\\0_1094.jpg', 'Food-5K\\training\\0_1095.jpg', 'Food-5K\\training\\0_1096.jpg', 'Food-5K\\training\\0_1097.jpg', 'Food-5K\\training\\0_1098.jpg', 'Food-5K\\training\\0_1099.jpg', 'Food-5K\\training\\0_11.jpg', 'Food-5K\\training\\0_110.jpg', 'Food-5K\\training\\0_1100.jpg', 'Food-5K\\training\\0_1101.jpg', 'Food-5K\\training\\0_1102.jpg', 'Food-5K\\training\\0_1103.jpg', 'Food-5K\\training\\0_1104.jpg', 'Food-5K\\training\\0_1105.jpg', 'Food-5K\\training\\0_1106. ...
# 0_0.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1.jpg
# non_food
# dataset\training\non_food
# hi
# 0_10.jpg
# non_food
# dataset\training\non_food
# hi
# 0_100.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1000.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1001.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1002.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1003.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1004.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1005.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1006.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1007.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1008.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1009.jpg
# non_food
# dataset\training\non_food
# hi
# 0_101.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1010.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1011.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1012.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1013.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1014.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1015.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1016.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1017.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1018.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1019.jpg
# non_food
# dataset\training\non_food
# hi
# 0_102.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1020.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1021.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1022.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1023.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1024.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1025.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1026.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1027.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1028.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1029.jpg
# non_food
# dataset\training\non_food
# hi
# 0_103.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1030.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1031.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1032.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1033.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1034.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1035.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1036.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1037.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1038.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1039.jpg
# non_food
# dataset\training\non_food
# hi
# 0_104.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1040.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1041.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1042.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1043.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1044.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1045.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1046.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1047.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1048.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1049.jpg
# non_food
# dataset\training\non_food
# hi
# 0_105.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1050.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1051.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1052.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1053.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1054.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1055.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1056.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1057.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1058.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1059.jpg
# non_food
# dataset\training\non_food
# hi
# 0_106.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1060.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1061.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1062.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1063.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1064.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1065.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1066.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1067.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1068.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1069.jpg
# non_food
# dataset\training\non_food
# hi
# 0_107.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1070.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1071.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1072.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1073.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1074.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1075.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1076.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1077.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1078.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1079.jpg
# non_food
# dataset\training\non_food
# hi
# 0_108.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1080.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1081.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1082.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1083.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1084.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1085.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1086.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1087.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1088.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1089.jpg
# non_food
# dataset\training\non_food
# hi
# 0_109.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1090.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1091.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1092.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1093.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1094.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1095.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1096.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1097.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1098.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1099.jpg
# non_food
# dataset\training\non_food
# hi
# 0_11.jpg
# non_food
# dataset\training\non_food
# hi
# 0_110.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1100.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1101.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1102.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1103.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1104.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1105.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1106.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1107.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1108.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1109.jpg
# non_food
# dataset\training\non_food
# hi
# 0_111.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1110.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1111.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1112.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1113.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1114.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1115.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1116.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1117.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1118.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1119.jpg
# non_food
# dataset\training\non_food
# hi
# 0_112.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1120.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1121.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1122.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1123.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1124.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1125.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1126.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1127.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1128.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1129.jpg
# non_food
# dataset\training\non_food
# hi
# 0_113.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1130.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1131.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1132.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1133.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1134.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1135.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1136.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1137.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1138.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1139.jpg
# non_food
# dataset\training\non_food
# hi
# 0_114.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1140.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1141.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1142.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1143.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1144.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1145.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1146.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1147.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1148.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1149.jpg
# non_food
# dataset\training\non_food
# hi
# 0_115.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1150.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1151.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1152.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1153.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1154.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1155.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1156.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1157.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1158.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1159.jpg
# non_food
# dataset\training\non_food
# hi
# 0_116.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1160.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1161.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1162.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1163.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1164.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1165.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1166.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1167.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1168.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1169.jpg
# non_food
# dataset\training\non_food
# hi
# 0_117.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1170.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1171.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1172.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1173.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1174.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1175.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1176.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1177.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1178.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1179.jpg
# non_food
# dataset\training\non_food
# hi
# 0_118.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1180.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1181.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1182.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1183.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1184.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1185.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1186.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1187.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1188.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1189.jpg
# non_food
# dataset\training\non_food
# hi
# 0_119.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1190.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1191.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1192.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1193.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1194.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1195.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1196.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1197.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1198.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1199.jpg
# non_food
# dataset\training\non_food
# hi
# 0_12.jpg
# non_food
# dataset\training\non_food
# hi
# 0_120.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1200.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1201.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1202.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1203.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1204.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1205.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1206.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1207.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1208.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1209.jpg
# non_food
# dataset\training\non_food
# hi
# 0_121.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1210.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1211.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1212.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1213.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1214.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1215.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1216.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1217.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1218.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1219.jpg
# non_food
# dataset\training\non_food
# hi
# 0_122.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1220.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1221.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1222.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1223.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1224.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1225.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1226.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1227.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1228.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1229.jpg
# non_food
# dataset\training\non_food
# hi
# 0_123.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1230.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1231.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1232.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1233.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1234.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1235.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1236.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1237.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1238.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1239.jpg
# non_food
# dataset\training\non_food
# hi
# 0_124.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1240.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1241.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1242.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1243.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1244.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1245.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1246.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1247.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1248.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1249.jpg
# non_food
# dataset\training\non_food
# hi
# 0_125.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1250.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1251.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1252.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1253.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1254.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1255.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1256.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1257.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1258.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1259.jpg
# non_food
# dataset\training\non_food
# hi
# 0_126.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1260.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1261.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1262.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1263.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1264.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1265.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1266.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1267.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1268.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1269.jpg
# non_food
# dataset\training\non_food
# hi
# 0_127.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1270.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1271.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1272.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1273.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1274.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1275.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1276.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1277.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1278.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1279.jpg
# non_food
# dataset\training\non_food
# hi
# 0_128.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1280.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1281.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1282.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1283.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1284.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1285.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1286.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1287.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1288.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1289.jpg
# non_food
# dataset\training\non_food
# hi
# 0_129.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1290.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1291.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1292.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1293.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1294.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1295.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1296.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1297.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1298.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1299.jpg
# non_food
# dataset\training\non_food
# hi
# 0_13.jpg
# non_food
# dataset\training\non_food
# hi
# 0_130.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1300.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1301.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1302.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1303.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1304.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1305.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1306.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1307.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1308.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1309.jpg
# non_food
# dataset\training\non_food
# hi
# 0_131.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1310.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1311.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1312.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1313.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1314.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1315.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1316.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1317.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1318.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1319.jpg
# non_food
# dataset\training\non_food
# hi
# 0_132.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1320.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1321.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1322.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1323.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1324.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1325.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1326.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1327.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1328.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1329.jpg
# non_food
# dataset\training\non_food
# hi
# 0_133.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1330.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1331.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1332.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1333.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1334.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1335.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1336.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1337.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1338.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1339.jpg
# non_food
# dataset\training\non_food
# hi
# 0_134.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1340.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1341.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1342.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1343.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1344.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1345.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1346.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1347.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1348.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1349.jpg
# non_food
# dataset\training\non_food
# hi
# 0_135.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1350.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1351.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1352.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1353.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1354.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1355.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1356.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1357.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1358.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1359.jpg
# non_food
# dataset\training\non_food
# hi
# 0_136.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1360.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1361.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1362.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1363.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1364.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1365.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1366.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1367.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1368.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1369.jpg
# non_food
# dataset\training\non_food
# hi
# 0_137.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1370.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1371.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1372.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1373.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1374.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1375.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1376.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1377.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1378.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1379.jpg
# non_food
# dataset\training\non_food
# hi
# 0_138.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1380.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1381.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1382.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1383.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1384.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1385.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1386.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1387.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1388.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1389.jpg
# non_food
# dataset\training\non_food
# hi
# 0_139.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1390.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1391.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1392.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1393.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1394.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1395.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1396.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1397.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1398.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1399.jpg
# non_food
# dataset\training\non_food
# hi
# 0_14.jpg
# non_food
# dataset\training\non_food
# hi
# 0_140.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1400.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1401.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1402.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1403.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1404.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1405.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1406.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1407.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1408.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1409.jpg
# non_food
# dataset\training\non_food
# hi
# 0_141.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1410.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1411.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1412.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1413.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1414.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1415.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1416.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1417.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1418.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1419.jpg
# non_food
# dataset\training\non_food
# hi
# 0_142.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1420.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1421.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1422.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1423.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1424.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1425.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1426.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1427.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1428.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1429.jpg
# non_food
# dataset\training\non_food
# hi
# 0_143.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1430.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1431.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1432.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1433.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1434.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1435.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1436.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1437.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1438.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1439.jpg
# non_food
# dataset\training\non_food
# hi
# 0_144.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1440.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1441.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1442.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1443.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1444.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1445.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1446.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1447.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1448.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1449.jpg
# non_food
# dataset\training\non_food
# hi
# 0_145.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1450.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1451.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1452.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1453.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1454.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1455.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1456.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1457.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1458.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1459.jpg
# non_food
# dataset\training\non_food
# hi
# 0_146.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1460.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1461.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1462.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1463.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1464.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1465.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1466.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1467.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1468.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1469.jpg
# non_food
# dataset\training\non_food
# hi
# 0_147.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1470.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1471.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1472.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1473.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1474.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1475.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1476.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1477.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1478.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1479.jpg
# non_food
# dataset\training\non_food
# hi
# 0_148.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1480.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1481.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1482.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1483.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1484.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1485.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1486.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1487.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1488.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1489.jpg
# non_food
# dataset\training\non_food
# hi
# 0_149.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1490.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1491.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1492.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1493.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1494.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1495.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1496.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1497.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1498.jpg
# non_food
# dataset\training\non_food
# hi
# 0_1499.jpg
# non_food
# dataset\training\non_food
# hi
# 0_15.jpg
# non_food
# dataset\training\non_food
# hi
# 0_150.jpg
# non_food
# dataset\training\non_food
# hi
# 0_151.jpg
# non_food
# dataset\training\non_food
# hi
# 0_152.jpg
# non_food
# dataset\training\non_food
# hi
# 0_153.jpg
# non_food
# dataset\training\non_food
# hi
# 0_154.jpg
# non_food
# dataset\training\non_food
# hi
# 0_155.jpg
# non_food
# dataset\training\non_food
# hi
# 0_156.jpg
# non_food
# dataset\training\non_food
# hi
# 0_157.jpg
# non_food
# dataset\training\non_food
# hi
# 0_158.jpg
# non_food
# dataset\training\non_food
# hi
# 0_159.jpg
# non_food
# dataset\training\non_food
# hi
# 0_16.jpg
# non_food
# dataset\training\non_food
# hi
# 0_160.jpg
# non_food
# dataset\training\non_food
# hi
# 0_161.jpg
# non_food
# dataset\training\non_food
# hi
# 0_162.jpg
# non_food
# dataset\training\non_food
# hi
# 0_163.jpg
# non_food
# dataset\training\non_food
# hi
# 0_164.jpg
# non_food
# dataset\training\non_food
# hi
# 0_165.jpg
# non_food
# dataset\training\non_food
# hi
# 0_166.jpg
# non_food
# dataset\training\non_food
# hi
# 0_167.jpg
# non_food
# dataset\training\non_food
# hi
# 0_168.jpg
# non_food
# dataset\training\non_food
# hi
# 0_169.jpg
# non_food
# dataset\training\non_food
# hi
# 0_17.jpg
# non_food
# dataset\training\non_food
# hi
# 0_170.jpg
# non_food
# dataset\training\non_food
# hi
# 0_171.jpg
# non_food
# dataset\training\non_food
# hi
# 0_172.jpg
# non_food
# dataset\training\non_food
# hi
# 0_173.jpg
# non_food
# dataset\training\non_food
# hi
# 0_174.jpg
# non_food
# dataset\training\non_food
# hi
# 0_175.jpg
# non_food
# dataset\training\non_food
# hi
# 0_176.jpg
# non_food
# dataset\training\non_food
# hi
# 0_177.jpg
# non_food
# dataset\training\non_food
# hi
# 0_178.jpg
# non_food
# dataset\training\non_food
# hi
# 0_179.jpg
# non_food
# dataset\training\non_food
# hi
# 0_18.jpg
# non_food
# dataset\training\non_food
# hi
# 0_180.jpg
# non_food
# dataset\training\non_food
# hi
# 0_181.jpg
# non_food
# dataset\training\non_food
# hi
# 0_182.jpg
# non_food
# dataset\training\non_food
# hi
# 0_183.jpg
# non_food
# dataset\training\non_food
# hi
# 0_184.jpg
# non_food
# dataset\training\non_food
# hi
# 0_185.jpg
# non_food
# dataset\training\non_food
# hi
# 0_186.jpg
# non_food
# dataset\training\non_food
# hi
# 0_187.jpg
# non_food
# dataset\training\non_food
# hi
# 0_188.jpg
# non_food
# dataset\training\non_food
# hi
# 0_189.jpg
# non_food
# dataset\training\non_food
# hi
# 0_19.jpg
# non_food
# dataset\training\non_food
# hi
# 0_190.jpg
# non_food
# dataset\training\non_food
# hi
# 0_191.jpg
# non_food
# dataset\training\non_food
# hi
# 0_192.jpg
# non_food
# dataset\training\non_food
# hi
# 0_193.jpg
# non_food
# dataset\training\non_food
# hi
# 0_194.jpg
# non_food
# dataset\training\non_food
# hi
# 0_195.jpg
# non_food
# dataset\training\non_food
# hi
# 0_196.jpg
# non_food
# dataset\training\non_food
# hi
# 0_197.jpg
# non_food
# dataset\training\non_food
# hi
# 0_198.jpg
# non_food
# dataset\training\non_food
# hi
# 0_199.jpg
# non_food
# dataset\training\non_food
# hi
# 0_2.jpg
# non_food
# dataset\training\non_food
# hi
# 0_20.jpg
# non_food
# dataset\training\non_food
# hi
# 0_200.jpg
# non_food
# dataset\training\non_food
# hi
# 0_201.jpg
# non_food
# dataset\training\non_food
# hi
# 0_202.jpg
# non_food
# dataset\training\non_food
# hi
# 0_203.jpg
# non_food
# dataset\training\non_food
# hi
# 0_204.jpg
# non_food
# dataset\training\non_food
# hi
# 0_205.jpg
# non_food
# dataset\training\non_food
# hi
# 0_206.jpg
# non_food
# dataset\training\non_food
# hi
# 0_207.jpg
# non_food
# dataset\training\non_food
# hi
# 0_208.jpg
# non_food
# dataset\training\non_food
# hi
# 0_209.jpg
# non_food
# dataset\training\non_food
# hi
# 0_21.jpg
# non_food
# dataset\training\non_food
# hi
# 0_210.jpg
# non_food
# dataset\training\non_food
# hi
# 0_211.jpg
# non_food
# dataset\training\non_food
# hi
# 0_212.jpg
# non_food
# dataset\training\non_food
# hi
# 0_213.jpg
# non_food
# dataset\training\non_food
# hi
# 0_214.jpg
# non_food
# dataset\training\non_food
# hi
# 0_215.jpg
# non_food
# dataset\training\non_food
# hi
# 0_216.jpg
# non_food
# dataset\training\non_food
# hi
# 0_217.jpg
# non_food
# dataset\training\non_food
# hi
# 0_218.jpg
# non_food
# dataset\training\non_food
# hi
# 0_219.jpg
# non_food
# dataset\training\non_food
# hi
# 0_22.jpg
# non_food
# dataset\training\non_food
# hi
# 0_220.jpg
# non_food
# dataset\training\non_food
# hi
# 0_221.jpg
# non_food
# dataset\training\non_food
# hi
# 0_222.jpg
# non_food
# dataset\training\non_food
# hi
# 0_223.jpg
# non_food
# dataset\training\non_food
# hi
# 0_224.jpg
# non_food
# dataset\training\non_food
# hi
# 0_225.jpg
# non_food
# dataset\training\non_food
# hi
# 0_226.jpg
# non_food
# dataset\training\non_food
# hi
# 0_227.jpg
# non_food
# dataset\training\non_food
# hi
# 0_228.jpg
# non_food
# dataset\training\non_food
# hi
# 0_229.jpg
# non_food
# dataset\training\non_food
# hi
# 0_23.jpg
# non_food
# dataset\training\non_food
# hi
# 0_230.jpg
# non_food
# dataset\training\non_food
# hi
# 0_231.jpg
# non_food
# dataset\training\non_food
# hi
# 0_232.jpg
# non_food
# dataset\training\non_food
# hi
# 0_233.jpg
# non_food
# dataset\training\non_food
# hi
# 0_234.jpg
# non_food
# dataset\training\non_food
# hi
# 0_235.jpg
# non_food
# dataset\training\non_food
# hi
# 0_236.jpg
# non_food
# dataset\training\non_food
# hi
# 0_237.jpg
# non_food
# dataset\training\non_food
# hi
# 0_238.jpg
# non_food
# dataset\training\non_food
# hi
# 0_239.jpg
# non_food
# dataset\training\non_food
# hi
# 0_24.jpg
# non_food
# dataset\training\non_food
# hi
# 0_240.jpg
# non_food
# dataset\training\non_food
# hi
# 0_241.jpg
# non_food
# dataset\training\non_food
# hi
# 0_242.jpg
# non_food
# dataset\training\non_food
# hi
# 0_243.jpg
# non_food
# dataset\training\non_food
# hi
# 0_244.jpg
# non_food
# dataset\training\non_food
# hi
# 0_245.jpg
# non_food
# dataset\training\non_food
# hi
# 0_246.jpg
# non_food
# dataset\training\non_food
# hi
# 0_247.jpg
# non_food
# dataset\training\non_food
# hi
# 0_248.jpg
# non_food
# dataset\training\non_food
# hi
# 0_249.jpg
# non_food
# dataset\training\non_food
# hi
# 0_25.jpg
# non_food
# dataset\training\non_food
# hi
# 0_250.jpg
# non_food
# dataset\training\non_food
# hi
# 0_251.jpg
# non_food
# dataset\training\non_food
# hi
# 0_252.jpg
# non_food
# dataset\training\non_food
# hi
# 0_253.jpg
# non_food
# dataset\training\non_food
# hi
# 0_254.jpg
# non_food
# dataset\training\non_food
# hi
# 0_255.jpg
# non_food
# dataset\training\non_food
# hi
# 0_256.jpg
# non_food
# dataset\training\non_food
# hi
# 0_257.jpg
# non_food
# dataset\training\non_food
# hi
# 0_258.jpg
# non_food
# dataset\training\non_food
# hi
# 0_259.jpg
# non_food
# dataset\training\non_food
# hi
# 0_26.jpg
# non_food
# dataset\training\non_food
# hi
# 0_260.jpg
# non_food
# dataset\training\non_food
# hi
# 0_261.jpg
# non_food
# dataset\training\non_food
# hi
# 0_262.jpg
# non_food
# dataset\training\non_food
# hi
# 0_263.jpg
# non_food
# dataset\training\non_food
# hi
# 0_264.jpg
# non_food
# dataset\training\non_food
# hi
# 0_265.jpg
# non_food
# dataset\training\non_food
# hi
# 0_266.jpg
# non_food
# dataset\training\non_food
# hi
# 0_267.jpg
# non_food
# dataset\training\non_food
# hi
# 0_268.jpg
# non_food
# dataset\training\non_food
# hi
# 0_269.jpg
# non_food
# dataset\training\non_food
# hi
# 0_27.jpg
# non_food
# dataset\training\non_food
# hi
# 0_270.jpg
# non_food
# dataset\training\non_food
# hi
# 0_271.jpg
# non_food
# dataset\training\non_food
# hi
# 0_272.jpg
# non_food
# dataset\training\non_food
# hi
# 0_273.jpg
# non_food
# dataset\training\non_food
# hi
# 0_274.jpg
# non_food
# dataset\training\non_food
# hi
# 0_275.jpg
# non_food
# dataset\training\non_food
# hi
# 0_276.jpg
# non_food
# dataset\training\non_food
# hi
# 0_277.jpg
# non_food
# dataset\training\non_food
# hi
# 0_278.jpg
# non_food
# dataset\training\non_food
# hi
# 0_279.jpg
# non_food
# dataset\training\non_food
# hi
# 0_28.jpg
# non_food
# dataset\training\non_food
# hi
# 0_280.jpg
# non_food
# dataset\training\non_food
# hi
# 0_281.jpg
# non_food
# dataset\training\non_food
# hi
# 0_282.jpg
# non_food
# dataset\training\non_food
# hi
# 0_283.jpg
# non_food
# dataset\training\non_food
# hi
# 0_284.jpg
# non_food
# dataset\training\non_food
# hi
# 0_285.jpg
# non_food
# dataset\training\non_food
# hi
# 0_286.jpg
# non_food
# dataset\training\non_food
# hi
# 0_287.jpg
# non_food
# dataset\training\non_food
# hi
# 0_288.jpg
# non_food
# dataset\training\non_food
# hi
# 0_289.jpg
# non_food
# dataset\training\non_food
# hi
# 0_29.jpg
# non_food
# dataset\training\non_food
# hi
# 0_290.jpg
# non_food
# dataset\training\non_food
# hi
# 0_291.jpg
# non_food
# dataset\training\non_food
# hi
# 0_292.jpg
# non_food
# dataset\training\non_food
# hi
# 0_293.jpg
# non_food
# dataset\training\non_food
# hi
# 0_294.jpg
# non_food
# dataset\training\non_food
# hi
# 0_295.jpg
# non_food
# dataset\training\non_food
# hi
# 0_296.jpg
# non_food
# dataset\training\non_food
# hi
# 0_297.jpg
# non_food
# dataset\training\non_food
# hi
# 0_298.jpg
# non_food
# dataset\training\non_food
# hi
# 0_299.jpg
# non_food
# dataset\training\non_food
# hi
# 0_3.jpg
# non_food
# dataset\training\non_food
# hi
# 0_30.jpg
# non_food
# dataset\training\non_food
# hi
# 0_300.jpg
# non_food
# dataset\training\non_food
# hi
# 0_301.jpg
# non_food
# dataset\training\non_food
# hi
# 0_302.jpg
# non_food
# dataset\training\non_food
# hi
# 0_303.jpg
# non_food
# dataset\training\non_food
# hi
# 0_304.jpg
# non_food
# dataset\training\non_food
# hi
# 0_305.jpg
# non_food
# dataset\training\non_food
# hi
# 0_306.jpg
# non_food
# dataset\training\non_food
# hi
# 0_307.jpg
# non_food
# dataset\training\non_food
# hi
# 0_308.jpg
# non_food
# dataset\training\non_food
# hi
# 0_309.jpg
# non_food
# dataset\training\non_food
# hi
# 0_31.jpg
# non_food
# dataset\training\non_food
# hi
# 0_310.jpg
# non_food
# dataset\training\non_food
# hi
# 0_311.jpg
# non_food
# dataset\training\non_food
# hi
# 0_312.jpg
# non_food
# dataset\training\non_food
# hi
# 0_313.jpg
# non_food
# dataset\training\non_food
# hi
# 0_314.jpg
# non_food
# dataset\training\non_food
# hi
# 0_315.jpg
# non_food
# dataset\training\non_food
# hi
# 0_316.jpg
# non_food
# dataset\training\non_food
# hi
# 0_317.jpg
# non_food
# dataset\training\non_food
# hi
# 0_318.jpg
# non_food
# dataset\training\non_food
# hi
# 0_319.jpg
# non_food
# dataset\training\non_food
# hi
# 0_32.jpg
# non_food
# dataset\training\non_food
# hi
# 0_320.jpg
# non_food
# dataset\training\non_food
# hi
# 0_321.jpg
# non_food
# dataset\training\non_food
# hi
# 0_322.jpg
# non_food
# dataset\training\non_food
# hi
# 0_323.jpg
# non_food
# dataset\training\non_food
# hi
# 0_324.jpg
# non_food
# dataset\training\non_food
# hi
# 0_325.jpg
# non_food
# dataset\training\non_food
# hi
# 0_326.jpg
# non_food
# dataset\training\non_food
# hi
# 0_327.jpg
# non_food
# dataset\training\non_food
# hi
# 0_328.jpg
# non_food
# dataset\training\non_food
# hi
# 0_329.jpg
# non_food
# dataset\training\non_food
# hi
# 0_33.jpg
# non_food
# dataset\training\non_food
# hi
# 0_330.jpg
# non_food
# dataset\training\non_food
# hi
# 0_331.jpg
# non_food
# dataset\training\non_food
# hi
# 0_332.jpg
# non_food
# dataset\training\non_food
# hi
# 0_333.jpg
# non_food
# dataset\training\non_food
# hi
# 0_334.jpg
# non_food
# dataset\training\non_food
# hi
# 0_335.jpg
# non_food
# dataset\training\non_food
# hi
# 0_336.jpg
# non_food
# dataset\training\non_food
# hi
# 0_337.jpg
# non_food
# dataset\training\non_food
# hi
# 0_338.jpg
# non_food
# dataset\training\non_food
# hi
# 0_339.jpg
# non_food
# dataset\training\non_food
# hi
# 0_34.jpg
# non_food
# dataset\training\non_food
# hi
# 0_340.jpg
# non_food
# dataset\training\non_food
# hi
# 0_341.jpg
# non_food
# dataset\training\non_food
# hi
# 0_342.jpg
# non_food
# dataset\training\non_food
# hi
# 0_343.jpg
# non_food
# dataset\training\non_food
# hi
# 0_344.jpg
# non_food
# dataset\training\non_food
# hi
# 0_345.jpg
# non_food
# dataset\training\non_food
# hi
# 0_346.jpg
# non_food
# dataset\training\non_food
# hi
# 0_347.jpg
# non_food
# dataset\training\non_food
# hi
# 0_348.jpg
# non_food
# dataset\training\non_food
# hi
# 0_349.jpg
# non_food
# dataset\training\non_food
# hi
# 0_35.jpg
# non_food
# dataset\training\non_food
# hi
# 0_350.jpg
# non_food
# dataset\training\non_food
# hi
# 0_351.jpg
# non_food
# dataset\training\non_food
# hi
# 0_352.jpg
# non_food
# dataset\training\non_food
# hi
# 0_353.jpg
# non_food
# dataset\training\non_food
# hi
# 0_354.jpg
# non_food
# dataset\training\non_food
# hi
# 0_355.jpg
# non_food
# dataset\training\non_food
# hi
# 0_356.jpg
# non_food
# dataset\training\non_food
# hi
# 0_357.jpg
# non_food
# dataset\training\non_food
# hi
# 0_358.jpg
# non_food
# dataset\training\non_food
# hi
# 0_359.jpg
# non_food
# dataset\training\non_food
# hi
# 0_36.jpg
# non_food
# dataset\training\non_food
# hi
# 0_360.jpg
# non_food
# dataset\training\non_food
# hi
# 0_361.jpg
# non_food
# dataset\training\non_food
# hi
# 0_362.jpg
# non_food
# dataset\training\non_food
# hi
# 0_363.jpg
# non_food
# dataset\training\non_food
# hi
# 0_364.jpg
# non_food
# dataset\training\non_food
# hi
# 0_365.jpg
# non_food
# dataset\training\non_food
# hi
# 0_366.jpg
# non_food
# dataset\training\non_food
# hi
# 0_367.jpg
# non_food
# dataset\training\non_food
# hi
# 0_368.jpg
# non_food
# dataset\training\non_food
# hi
# 0_369.jpg
# non_food
# dataset\training\non_food
# hi
# 0_37.jpg
# non_food
# dataset\training\non_food
# hi
# 0_370.jpg
# non_food
# dataset\training\non_food
# hi
# 0_371.jpg
# non_food
# dataset\training\non_food
# hi
# 0_372.jpg
# non_food
# dataset\training\non_food
# hi
# 0_373.jpg
# non_food
# dataset\training\non_food
# hi
# 0_374.jpg
# non_food
# dataset\training\non_food
# hi
# 0_375.jpg
# non_food
# dataset\training\non_food
# hi
# 0_376.jpg
# non_food
# dataset\training\non_food
# hi
# 0_377.jpg
# non_food
# dataset\training\non_food
# hi
# 0_378.jpg
# non_food
# dataset\training\non_food
# hi
# 0_379.jpg
# non_food
# dataset\training\non_food
# hi
# 0_38.jpg
# non_food
# dataset\training\non_food
# hi
# 0_380.jpg
# non_food
# dataset\training\non_food
# hi
# 0_381.jpg
# non_food
# dataset\training\non_food
# hi
# 0_382.jpg
# non_food
# dataset\training\non_food
# hi
# 0_383.jpg
# non_food
# dataset\training\non_food
# hi
# 0_384.jpg
# non_food
# dataset\training\non_food
# hi
# 0_385.jpg
# non_food
# dataset\training\non_food
# hi
# 0_386.jpg
# non_food
# dataset\training\non_food
# hi
# 0_387.jpg
# non_food
# dataset\training\non_food
# hi
# 0_388.jpg
# non_food
# dataset\training\non_food
# hi
# 0_389.jpg
# non_food
# dataset\training\non_food
# hi
# 0_39.jpg
# non_food
# dataset\training\non_food
# hi
# 0_390.jpg
# non_food
# dataset\training\non_food
# hi
# 0_391.jpg
# non_food
# dataset\training\non_food
# hi
# 0_392.jpg
# non_food
# dataset\training\non_food
# hi
# 0_393.jpg
# non_food
# dataset\training\non_food
# hi
# 0_394.jpg
# non_food
# dataset\training\non_food
# hi
# 0_395.jpg
# non_food
# dataset\training\non_food
# hi
# 0_396.jpg
# non_food
# dataset\training\non_food
# hi
# 0_397.jpg
# non_food
# dataset\training\non_food
# hi
# 0_398.jpg
# non_food
# dataset\training\non_food
# hi
# 0_399.jpg
# non_food
# dataset\training\non_food
# hi
# 0_4.jpg
# non_food
# dataset\training\non_food
# hi
# 0_40.jpg
# non_food
# dataset\training\non_food
# hi
# 0_400.jpg
# non_food
# dataset\training\non_food
# hi
# 0_401.jpg
# non_food
# dataset\training\non_food
# hi
# 0_402.jpg
# non_food
# dataset\training\non_food
# hi
# 0_403.jpg
# non_food
# dataset\training\non_food
# hi
# 0_404.jpg
# non_food
# dataset\training\non_food
# hi
# 0_405.jpg
# non_food
# dataset\training\non_food
# hi
# 0_406.jpg
# non_food
# dataset\training\non_food
# hi
# 0_407.jpg
# non_food
# dataset\training\non_food
# hi
# 0_408.jpg
# non_food
# dataset\training\non_food
# hi
# 0_409.jpg
# non_food
# dataset\training\non_food
# hi
# 0_41.jpg
# non_food
# dataset\training\non_food
# hi
# 0_410.jpg
# non_food
# dataset\training\non_food
# hi
# 0_411.jpg
# non_food
# dataset\training\non_food
# hi
# 0_412.jpg
# non_food
# dataset\training\non_food
# hi
# 0_413.jpg
# non_food
# dataset\training\non_food
# hi
# 0_414.jpg
# non_food
# dataset\training\non_food
# hi
# 0_415.jpg
# non_food
# dataset\training\non_food
# hi
# 0_416.jpg
# non_food
# dataset\training\non_food
# hi
# 0_417.jpg
# non_food
# dataset\training\non_food
# hi
# 0_418.jpg
# non_food
# dataset\training\non_food
# hi
# 0_419.jpg
# non_food
# dataset\training\non_food
# hi
# 0_42.jpg
# non_food
# dataset\training\non_food
# hi
# 0_420.jpg
# non_food
# dataset\training\non_food
# hi
# 0_421.jpg
# non_food
# dataset\training\non_food
# hi
# 0_422.jpg
# non_food
# dataset\training\non_food
# hi
# 0_423.jpg
# non_food
# dataset\training\non_food
# hi
# 0_424.jpg
# non_food
# dataset\training\non_food
# hi
# 0_425.jpg
# non_food
# dataset\training\non_food
# hi
# 0_426.jpg
# non_food
# dataset\training\non_food
# hi
# 0_427.jpg
# non_food
# dataset\training\non_food
# hi
# 0_428.jpg
# non_food
# dataset\training\non_food
# hi
# 0_429.jpg
# non_food
# dataset\training\non_food
# hi
# 0_43.jpg
# non_food
# dataset\training\non_food
# hi
# 0_430.jpg
# non_food
# dataset\training\non_food
# hi
# 0_431.jpg
# non_food
# dataset\training\non_food
# hi
# 0_432.jpg
# non_food
# dataset\training\non_food
# hi
# 0_433.jpg
# non_food
# dataset\training\non_food
# hi
# 0_434.jpg
# non_food
# dataset\training\non_food
# hi
# 0_435.jpg
# non_food
# dataset\training\non_food
# hi
# 0_436.jpg
# non_food
# dataset\training\non_food
# hi
# 0_437.jpg
# non_food
# dataset\training\non_food
# hi
# 0_438.jpg
# non_food
# dataset\training\non_food
# hi
# 0_439.jpg
# non_food
# dataset\training\non_food
# hi
# 0_44.jpg
# non_food
# dataset\training\non_food
# hi
# 0_440.jpg
# non_food
# dataset\training\non_food
# hi
# 0_441.jpg
# non_food
# dataset\training\non_food
# hi
# 0_442.jpg
# non_food
# dataset\training\non_food
# hi
# 0_443.jpg
# non_food
# dataset\training\non_food
# hi
# 0_444.jpg
# non_food
# dataset\training\non_food
# hi
# 0_445.jpg
# non_food
# dataset\training\non_food
# hi
# 0_446.jpg
# non_food
# dataset\training\non_food
# hi
# 0_447.jpg
# non_food
# dataset\training\non_food
# hi
# 0_448.jpg
# non_food
# dataset\training\non_food
# hi
# 0_449.jpg
# non_food
# dataset\training\non_food
# hi
# 0_45.jpg
# non_food
# dataset\training\non_food
# hi
# 0_450.jpg
# non_food
# dataset\training\non_food
# hi
# 0_451.jpg
# non_food
# dataset\training\non_food
# hi
# 0_452.jpg
# non_food
# dataset\training\non_food
# hi
# 0_453.jpg
# non_food
# dataset\training\non_food
# hi
# 0_454.jpg
# non_food
# dataset\training\non_food
# hi
# 0_455.jpg
# non_food
# dataset\training\non_food
# hi
# 0_456.jpg
# non_food
# dataset\training\non_food
# hi
# 0_457.jpg
# non_food
# dataset\training\non_food
# hi
# 0_458.jpg
# non_food
# dataset\training\non_food
# hi
# 0_459.jpg
# non_food
# dataset\training\non_food
# hi
# 0_46.jpg
# non_food
# dataset\training\non_food
# hi
# 0_460.jpg
# non_food
# dataset\training\non_food
# hi
# 0_461.jpg
# non_food
# dataset\training\non_food
# hi
# 0_462.jpg
# non_food
# dataset\training\non_food
# hi
# ...
# hi
# 1_203.jpg
# food
# dataset\validation\food
# hi
# 1_204.jpg
# food
# dataset\validation\food
# hi
# 1_205.jpg
# food
# dataset\validation\food
# hi
# 1_206.jpg
# food
# dataset\validation\food
# hi
# 1_207.jpg
# food
# dataset\validation\food
# hi
# 1_208.jpg
# food
# dataset\validation\food
# hi
# 1_209.jpg
# food
# dataset\validation\food
# hi
# 1_21.jpg
# food
# dataset\validation\food
# hi
# 1_210.jpg
# food
# dataset\validation\food
# hi
# 1_211.jpg
# food
# dataset\validation\food
# hi
# 1_212.jpg
# food
# dataset\validation\food
# hi
# 1_213.jpg
# food
# dataset\validation\food
# hi
# 1_214.jpg
# food
# dataset\validation\food
# hi
# 1_215.jpg
# food
# dataset\validation\food
# hi
# 1_216.jpg
# food
# dataset\validation\food
# hi
# 1_217.jpg
# food
# dataset\validation\food
# hi
# 1_218.jpg
# food
# dataset\validation\food
# hi
# 1_219.jpg
# food
# dataset\validation\food
# hi
# 1_22.jpg
# food
# dataset\validation\food
# hi
# 1_220.jpg
# food
# dataset\validation\food
# hi
# 1_221.jpg
# food
# dataset\validation\food
# hi
# 1_222.jpg
# food
# dataset\validation\food
# hi
# 1_223.jpg
# food
# dataset\validation\food
# hi
# 1_224.jpg
# food
# dataset\validation\food
# hi
# 1_225.jpg
# food
# dataset\validation\food
# hi
# 1_226.jpg
# food
# dataset\validation\food
# hi
# 1_227.jpg
# food
# dataset\validation\food
# hi
# 1_228.jpg
# food
# dataset\validation\food
# hi
# 1_229.jpg
# food
# dataset\validation\food
# hi
# 1_23.jpg
# food
# dataset\validation\food
# hi
# 1_230.jpg
# food
# dataset\validation\food
# hi
# 1_231.jpg
# food
# dataset\validation\food
# hi
# 1_232.jpg
# food
# dataset\validation\food
# hi
# 1_233.jpg
# food
# dataset\validation\food
# hi
# 1_234.jpg
# food
# dataset\validation\food
# hi
# 1_235.jpg
# food
# dataset\validation\food
# hi
# 1_236.jpg
# food
# dataset\validation\food
# hi
# 1_237.jpg
# food
# dataset\validation\food
# hi
# 1_238.jpg
# food
# dataset\validation\food
# hi
# 1_239.jpg
# food
# dataset\validation\food
# hi
# 1_24.jpg
# food
# dataset\validation\food
# hi
# 1_240.jpg
# food
# dataset\validation\food
# hi
# 1_241.jpg
# food
# dataset\validation\food
# hi
# 1_242.jpg
# food
# dataset\validation\food
# hi
# 1_243.jpg
# food
# dataset\validation\food
# hi
# 1_244.jpg
# food
# dataset\validation\food
# hi
# 1_245.jpg
# food
# dataset\validation\food
# hi
# 1_246.jpg
# food
# dataset\validation\food
# hi
# 1_247.jpg
# food
# dataset\validation\food
# hi
# 1_248.jpg
# food
# dataset\validation\food
# hi
# 1_249.jpg
# food
# dataset\validation\food
# hi
# 1_25.jpg
# food
# dataset\validation\food
# hi
# 1_250.jpg
# food
# dataset\validation\food
# hi
# 1_251.jpg
# food
# dataset\validation\food
# hi
# 1_252.jpg
# food
# dataset\validation\food
# hi
# 1_253.jpg
# food
# dataset\validation\food
# hi
# 1_254.jpg
# food
# dataset\validation\food
# hi
# 1_255.jpg
# food
# dataset\validation\food
# hi
# 1_256.jpg
# food
# dataset\validation\food
# hi
# 1_257.jpg
# food
# dataset\validation\food
# hi
# 1_258.jpg
# food
# dataset\validation\food
# hi
# 1_259.jpg
# food
# dataset\validation\food
# hi
# 1_26.jpg
# food
# dataset\validation\food
# hi
# 1_260.jpg
# food
# dataset\validation\food
# hi
# 1_261.jpg
# food
# dataset\validation\food
# hi
# 1_262.jpg
# food
# dataset\validation\food
# hi
# 1_263.jpg
# food
# dataset\validation\food
# hi
# 1_264.jpg
# food
# dataset\validation\food
# hi
# 1_265.jpg
# food
# dataset\validation\food
# hi
# 1_266.jpg
# food
# dataset\validation\food
# hi
# 1_267.jpg
# food
# dataset\validation\food
# hi
# 1_268.jpg
# food
# dataset\validation\food
# hi
# 1_269.jpg
# food
# dataset\validation\food
# hi
# 1_27.jpg
# food
# dataset\validation\food
# hi
# 1_270.jpg
# food
# dataset\validation\food
# hi
# 1_271.jpg
# food
# dataset\validation\food
# hi
# 1_272.jpg
# food
# dataset\validation\food
# hi
# 1_273.jpg
# food
# dataset\validation\food
# hi
# 1_274.jpg
# food
# dataset\validation\food
# hi
# 1_275.jpg
# food
# dataset\validation\food
# hi
# 1_276.jpg
# food
# dataset\validation\food
# hi
# 1_277.jpg
# food
# dataset\validation\food
# hi
# 1_278.jpg
# food
# dataset\validation\food
# hi
# 1_279.jpg
# food
# dataset\validation\food
# hi
# 1_28.jpg
# food
# dataset\validation\food
# hi
# 1_280.jpg
# food
# dataset\validation\food
# hi
# 1_281.jpg
# food
# dataset\validation\food
# hi
# 1_282.jpg
# food
# dataset\validation\food
# hi
# 1_283.jpg
# food
# dataset\validation\food
# hi
# 1_284.jpg
# food
# dataset\validation\food
# hi
# 1_285.jpg
# food
# dataset\validation\food
# hi
# 1_286.jpg
# food
# dataset\validation\food
# hi
# 1_287.jpg
# food
# dataset\validation\food
# hi
# 1_288.jpg
# food
# dataset\validation\food
# hi
# 1_289.jpg
# food
# dataset\validation\food
# hi
# 1_29.jpg
# food
# dataset\validation\food
# hi
# 1_290.jpg
# food
# dataset\validation\food
# hi
# 1_291.jpg
# food
# dataset\validation\food
# hi
# 1_292.jpg
# food
# dataset\validation\food
# hi
# 1_293.jpg
# food
# dataset\validation\food
# hi
# 1_294.jpg
# food
# dataset\validation\food
# hi
# 1_295.jpg
# food
# dataset\validation\food
# hi
# 1_296.jpg
# food
# dataset\validation\food
# hi
# 1_297.jpg
# food
# dataset\validation\food
# hi
# 1_298.jpg
# food
# dataset\validation\food
# hi
# 1_299.jpg
# food
# dataset\validation\food
# hi
# 1_3.jpg
# food
# dataset\validation\food
# hi
# 1_30.jpg
# food
# dataset\validation\food
# hi
# 1_300.jpg
# food
# dataset\validation\food
# hi
# 1_301.jpg
# food
# dataset\validation\food
# hi
# 1_302.jpg
# food
# dataset\validation\food
# hi
# 1_303.jpg
# food
# dataset\validation\food
# hi
# 1_304.jpg
# food
# dataset\validation\food
# hi
# 1_305.jpg
# food
# dataset\validation\food
# hi
# 1_306.jpg
# food
# dataset\validation\food
# hi
# 1_307.jpg
# food
# dataset\validation\food
# hi
# 1_308.jpg
# food
# dataset\validation\food
# hi
# 1_309.jpg
# food
# dataset\validation\food
# hi
# 1_31.jpg
# food
# dataset\validation\food
# hi
# 1_310.jpg
# food
# dataset\validation\food
# hi
# 1_311.jpg
# food
# dataset\validation\food
# hi
# 1_312.jpg
# food
# dataset\validation\food
# hi
# 1_313.jpg
# food
# dataset\validation\food
# hi
# 1_314.jpg
# food
# dataset\validation\food
# hi
# 1_315.jpg
# food
# dataset\validation\food
# hi
# 1_316.jpg
# food
# dataset\validation\food
# hi
# 1_317.jpg
# food
# dataset\validation\food
# hi
# 1_318.jpg
# food
# dataset\validation\food
# hi
# 1_319.jpg
# food
# dataset\validation\food
# hi
# 1_32.jpg
# food
# dataset\validation\food
# hi
# 1_320.jpg
# food
# dataset\validation\food
# hi
# 1_321.jpg
# food
# dataset\validation\food
# hi
# 1_322.jpg
# food
# dataset\validation\food
# hi
# 1_323.jpg
# food
# dataset\validation\food
# hi
# 1_324.jpg
# food
# dataset\validation\food
# hi
# 1_325.jpg
# food
# dataset\validation\food
# hi
# 1_326.jpg
# food
# dataset\validation\food
# hi
# 1_327.jpg
# food
# dataset\validation\food
# hi
# 1_328.jpg
# food
# dataset\validation\food
# hi
# 1_329.jpg
# food
# dataset\validation\food
# hi
# 1_33.jpg
# food
# dataset\validation\food
# hi
# 1_330.jpg
# food
# dataset\validation\food
# hi
# 1_331.jpg
# food
# dataset\validation\food
# hi
# 1_332.jpg
# food
# dataset\validation\food
# hi
# 1_333.jpg
# food
# dataset\validation\food
# hi
# 1_334.jpg
# food
# dataset\validation\food
# hi
# 1_335.jpg
# food
# dataset\validation\food
# hi
# 1_336.jpg
# food
# dataset\validation\food
# hi
# 1_337.jpg
# food
# dataset\validation\food
# hi
# 1_338.jpg
# food
# dataset\validation\food
# hi
# 1_339.jpg
# food
# dataset\validation\food
# hi
# 1_34.jpg
# food
# dataset\validation\food
# hi
# 1_340.jpg
# food
# dataset\validation\food
# hi
# 1_341.jpg
# food
# dataset\validation\food
# hi
# 1_342.jpg
# food
# dataset\validation\food
# hi
# 1_343.jpg
# food
# dataset\validation\food
# hi
# 1_344.jpg
# food
# dataset\validation\food
# hi
# 1_345.jpg
# food
# dataset\validation\food
# hi
# 1_346.jpg
# food
# dataset\validation\food
# hi
# 1_347.jpg
# food
# dataset\validation\food
# hi
# 1_348.jpg
# food
# dataset\validation\food
# hi
# 1_349.jpg
# food
# dataset\validation\food
# hi
# 1_35.jpg
# food
# dataset\validation\food
# hi
# 1_350.jpg
# food
# dataset\validation\food
# hi
# 1_351.jpg
# food
# dataset\validation\food
# hi
# 1_352.jpg
# food
# dataset\validation\food
# hi
# 1_353.jpg
# food
# dataset\validation\food
# hi
# 1_354.jpg
# food
# dataset\validation\food
# hi
# 1_355.jpg
# food
# dataset\validation\food
# hi
# 1_356.jpg
# food
# dataset\validation\food
# hi
# 1_357.jpg
# food
# dataset\validation\food
# hi
# 1_358.jpg
# food
# dataset\validation\food
# hi
# 1_359.jpg
# food
# dataset\validation\food
# hi
# 1_36.jpg
# food
# dataset\validation\food
# hi
# 1_360.jpg
# food
# dataset\validation\food
# hi
# 1_361.jpg
# food
# dataset\validation\food
# hi
# 1_362.jpg
# food
# dataset\validation\food
# hi
# 1_363.jpg
# food
# dataset\validation\food
# hi
# 1_364.jpg
# food
# dataset\validation\food
# hi
# 1_365.jpg
# food
# dataset\validation\food
# hi
# 1_366.jpg
# food
# dataset\validation\food
# hi
# 1_367.jpg
# food
# dataset\validation\food
# hi
# 1_368.jpg
# food
# dataset\validation\food
# hi
# 1_369.jpg
# food
# dataset\validation\food
# hi
# 1_37.jpg
# food
# dataset\validation\food
# hi
# 1_370.jpg
# food
# dataset\validation\food
# hi
# 1_371.jpg
# food
# dataset\validation\food
# hi
# 1_372.jpg
# food
# dataset\validation\food
# hi
# 1_373.jpg
# food
# dataset\validation\food
# hi
# 1_374.jpg
# food
# dataset\validation\food
# hi
# 1_375.jpg
# food
# dataset\validation\food
# hi
# 1_376.jpg
# food
# dataset\validation\food
# hi
# 1_377.jpg
# food
# dataset\validation\food
# hi
# 1_378.jpg
# food
# dataset\validation\food
# hi
# 1_379.jpg
# food
# dataset\validation\food
# hi
# 1_38.jpg
# food
# dataset\validation\food
# hi
# 1_380.jpg
# food
# dataset\validation\food
# hi
# 1_381.jpg
# food
# dataset\validation\food
# hi
# 1_382.jpg
# food
# dataset\validation\food
# hi
# 1_383.jpg
# food
# dataset\validation\food
# hi
# 1_384.jpg
# food
# dataset\validation\food
# hi
# 1_385.jpg
# food
# dataset\validation\food
# hi
# 1_386.jpg
# food
# dataset\validation\food
# hi
# 1_387.jpg
# food
# dataset\validation\food
# hi
# 1_388.jpg
# food
# dataset\validation\food
# hi
# 1_389.jpg
# food
# dataset\validation\food
# hi
# 1_39.jpg
# food
# dataset\validation\food
# hi
# 1_390.jpg
# food
# dataset\validation\food
# hi
# 1_391.jpg
# food
# dataset\validation\food
# hi
# 1_392.jpg
# food
# dataset\validation\food
# hi
# 1_393.jpg
# food
# dataset\validation\food
# hi
# 1_394.jpg
# food
# dataset\validation\food
# hi
# 1_395.jpg
# food
# dataset\validation\food
# hi
# 1_396.jpg
# food
# dataset\validation\food
# hi
# 1_397.jpg
# food
# dataset\validation\food
# hi
# 1_398.jpg
# food
# dataset\validation\food
# hi
# 1_399.jpg
# food
# dataset\validation\food
# hi
# 1_4.jpg
# food
# dataset\validation\food
# hi
# 1_40.jpg
# food
# dataset\validation\food
# hi
# 1_400.jpg
# food
# dataset\validation\food
# hi
# 1_401.jpg
# food
# dataset\validation\food
# hi
# 1_402.jpg
# food
# dataset\validation\food
# hi
# 1_403.jpg
# food
# dataset\validation\food
# hi
# 1_404.jpg
# food
# dataset\validation\food
# hi
# 1_405.jpg
# food
# dataset\validation\food
# hi
# 1_406.jpg
# food
# dataset\validation\food
# hi
# 1_407.jpg
# food
# dataset\validation\food
# hi
# 1_408.jpg
# food
# dataset\validation\food
# hi
# 1_409.jpg
# food
# dataset\validation\food
# hi
# 1_41.jpg
# food
# dataset\validation\food
# hi
# 1_410.jpg
# food
# dataset\validation\food
# hi
# 1_411.jpg
# food
# dataset\validation\food
# hi
# 1_412.jpg
# food
# dataset\validation\food
# hi
# 1_413.jpg
# food
# dataset\validation\food
# hi
# 1_414.jpg
# food
# dataset\validation\food
# hi
# 1_415.jpg
# food
# dataset\validation\food
# hi
# 1_416.jpg
# food
# dataset\validation\food
# hi
# 1_417.jpg
# food
# dataset\validation\food
# hi
# 1_418.jpg
# food
# dataset\validation\food
# hi
# 1_419.jpg
# food
# dataset\validation\food
# hi
# 1_42.jpg
# food
# dataset\validation\food
# hi
# 1_420.jpg
# food
# dataset\validation\food
# hi
# 1_421.jpg
# food
# dataset\validation\food
# hi
# 1_422.jpg
# food
# dataset\validation\food
# hi
# 1_423.jpg
# food
# dataset\validation\food
# hi
# 1_424.jpg
# food
# dataset\validation\food
# hi
# 1_425.jpg
# food
# dataset\validation\food
# hi
# 1_426.jpg
# food
# dataset\validation\food
# hi
# 1_427.jpg
# food
# dataset\validation\food
# hi
# 1_428.jpg
# food
# dataset\validation\food
# hi
# 1_429.jpg
# food
# dataset\validation\food
# hi
# 1_43.jpg
# food
# dataset\validation\food
# hi
# 1_430.jpg
# food
# dataset\validation\food
# hi
# 1_431.jpg
# food
# dataset\validation\food
# hi
# 1_432.jpg
# food
# dataset\validation\food
# hi
# 1_433.jpg
# food
# dataset\validation\food
# hi
# 1_434.jpg
# food
# dataset\validation\food
# hi
# 1_435.jpg
# food
# dataset\validation\food
# hi
# 1_436.jpg
# food
# dataset\validation\food
# hi
# 1_437.jpg
# food
# dataset\validation\food
# hi
# 1_438.jpg
# food
# dataset\validation\food
# hi
# 1_439.jpg
# food
# dataset\validation\food
# hi
# 1_44.jpg
# food
# dataset\validation\food
# hi
# 1_440.jpg
# food
# dataset\validation\food
# hi
# 1_441.jpg
# food
# dataset\validation\food
# hi
# 1_442.jpg
# food
# dataset\validation\food
# hi
# 1_443.jpg
# food
# dataset\validation\food
# hi
# 1_444.jpg
# food
# dataset\validation\food
# hi
# 1_445.jpg
# food
# dataset\validation\food
# hi
# 1_446.jpg
# food
# dataset\validation\food
# hi
# 1_447.jpg
# food
# dataset\validation\food
# hi
# 1_448.jpg
# food
# dataset\validation\food
# hi
# 1_449.jpg
# food
# dataset\validation\food
# hi
# 1_45.jpg
# food
# dataset\validation\food
# hi
# 1_450.jpg
# food
# dataset\validation\food
# hi
# 1_451.jpg
# food
# dataset\validation\food
# hi
# 1_452.jpg
# food
# dataset\validation\food
# hi
# 1_453.jpg
# food
# dataset\validation\food
# hi
# 1_454.jpg
# food
# dataset\validation\food
# hi
# 1_455.jpg
# food
# dataset\validation\food
# hi
# 1_456.jpg
# food
# dataset\validation\food
# hi
# 1_457.jpg
# food
# dataset\validation\food
# hi
# 1_458.jpg
# food
# dataset\validation\food
# hi
# 1_459.jpg
# food
# dataset\validation\food
# hi
# 1_46.jpg
# food
# dataset\validation\food
# hi
# 1_460.jpg
# food
# dataset\validation\food
# hi
# 1_461.jpg
# food
# dataset\validation\food
# hi
# 1_462.jpg
# food
# dataset\validation\food
# hi
# 1_463.jpg
# food
# dataset\validation\food
# hi
# 1_464.jpg
# food
# dataset\validation\food
# hi
# 1_465.jpg
# food
# dataset\validation\food
# hi
# 1_466.jpg
# food
# dataset\validation\food
# hi
# 1_467.jpg
# food
# dataset\validation\food
# hi
# 1_468.jpg
# food
# dataset\validation\food
# hi
# 1_469.jpg
# food
# dataset\validation\food
# hi
# 1_47.jpg
# food
# dataset\validation\food
# hi
# 1_470.jpg
# food
# dataset\validation\food
# hi
# 1_471.jpg
# food
# dataset\validation\food
# hi
# 1_472.jpg
# food
# dataset\validation\food
# hi
# 1_473.jpg
# food
# dataset\validation\food
# hi
# 1_474.jpg
# food
# dataset\validation\food
# hi
# 1_475.jpg
# food
# dataset\validation\food
# hi
# 1_476.jpg
# food
# dataset\validation\food
# hi
# 1_477.jpg
# food
# dataset\validation\food
# hi
# 1_478.jpg
# food
# dataset\validation\food
# hi
# 1_479.jpg
# food
# dataset\validation\food
# hi
# 1_48.jpg
# food
# dataset\validation\food
# hi
# 1_480.jpg
# food
# dataset\validation\food
# hi
# 1_481.jpg
# food
# dataset\validation\food
# hi
# 1_482.jpg
# food
# dataset\validation\food
# hi
# 1_483.jpg
# food
# dataset\validation\food
# hi
# 1_484.jpg
# food
# dataset\validation\food
# hi
# 1_485.jpg
# food
# dataset\validation\food
# hi
# 1_486.jpg
# food
# dataset\validation\food
# hi
# 1_487.jpg
# food
# dataset\validation\food
# hi
# 1_488.jpg
# food
# dataset\validation\food
# hi
# 1_489.jpg
# food
# dataset\validation\food
# hi
# 1_49.jpg
# food
# dataset\validation\food
# hi
# 1_490.jpg
# food
# dataset\validation\food
# hi
# 1_491.jpg
# food
# dataset\validation\food
# hi
# 1_492.jpg
# food
# dataset\validation\food
# hi
# 1_493.jpg
# food
# dataset\validation\food
# hi
# 1_494.jpg
# food
# dataset\validation\food
# hi
# 1_495.jpg
# food
# dataset\validation\food
# hi
# 1_496.jpg
# food
# dataset\validation\food
# hi
# 1_497.jpg
# food
# dataset\validation\food
# hi
# 1_498.jpg
# food
# dataset\validation\food
# hi
# 1_499.jpg
# food
# dataset\validation\food
# hi
# 1_5.jpg
# food
# dataset\validation\food
# hi
# 1_50.jpg
# food
# dataset\validation\food
# hi
# 1_51.jpg
# food
# dataset\validation\food
# hi
# 1_52.jpg
# food
# dataset\validation\food
# hi
# 1_53.jpg
# food
# dataset\validation\food
# hi
# 1_54.jpg
# food
# dataset\validation\food
# hi
# 1_55.jpg
# food
# dataset\validation\food
# hi
# 1_56.jpg
# food
# dataset\validation\food
# hi
# 1_57.jpg
# food
# dataset\validation\food
# hi
# 1_58.jpg
# food
# dataset\validation\food
# hi
# 1_59.jpg
# food
# dataset\validation\food
# hi
# 1_6.jpg
# food
# dataset\validation\food
# hi
# 1_60.jpg
# food
# dataset\validation\food
# hi
# 1_61.jpg
# food
# dataset\validation\food
# hi
# 1_62.jpg
# food
# dataset\validation\food
# hi
# 1_63.jpg
# food
# dataset\validation\food
# hi
# 1_64.jpg
# food
# dataset\validation\food
# hi
# 1_65.jpg
# food
# dataset\validation\food
# hi
# 1_66.jpg
# food
# dataset\validation\food
# hi
# 1_67.jpg
# food
# dataset\validation\food
# hi
# 1_68.jpg
# food
# dataset\validation\food
# hi
# 1_69.jpg
# food
# dataset\validation\food
# hi
# 1_7.jpg
# food
# dataset\validation\food
# hi
# 1_70.jpg
# food
# dataset\validation\food
# hi
# 1_71.jpg
# food
# dataset\validation\food
# hi
# 1_72.jpg
# food
# dataset\validation\food
# hi
# 1_73.jpg
# food
# dataset\validation\food
# hi
# 1_74.jpg
# food
# dataset\validation\food
# hi
# 1_75.jpg
# food
# dataset\validation\food
# hi
# 1_76.jpg
# food
# dataset\validation\food
# hi
# 1_77.jpg
# food
# dataset\validation\food
# hi
# 1_78.jpg
# food
# dataset\validation\food
# hi
# 1_79.jpg
# food
# dataset\validation\food
# hi
# 1_8.jpg
# food
# dataset\validation\food
# hi
# 1_80.jpg
# food
# dataset\validation\food
# hi
# 1_81.jpg
# food
# dataset\validation\food
# hi
# 1_82.jpg
# food
# dataset\validation\food
# hi
# 1_83.jpg
# food
# dataset\validation\food
# hi
# 1_84.jpg
# food
# dataset\validation\food
# hi
# 1_85.jpg
# food
# dataset\validation\food
# hi
# 1_86.jpg
# food
# dataset\validation\food
# hi
# 1_87.jpg
# food
# dataset\validation\food
# hi
# 1_88.jpg
# food
# dataset\validation\food
# hi
# 1_89.jpg
# food
# dataset\validation\food
# hi
# 1_9.jpg
# food
# dataset\validation\food
# hi
# 1_90.jpg
# food
# dataset\validation\food
# hi
# 1_91.jpg
# food
# dataset\validation\food
# hi
# 1_92.jpg
# food
# dataset\validation\food
# hi
# 1_93.jpg
# food
# dataset\validation\food
# hi
# 1_94.jpg
# food
# dataset\validation\food
# hi
# 1_95.jpg
# food
# dataset\validation\food
# hi
# 1_96.jpg
# food
# dataset\validation\food
# hi
# 1_97.jpg
# food
# dataset\validation\food
# hi
# 1_98.jpg
# food
# dataset\validation\food
# hi
# 1_99.jpg
# food
# dataset\validation\food
# hi

# %%
# import the necessary packages
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from pyimagesearch import config
from imutils import paths
import numpy as np
import pickle
import random
import os

# load the VGG16 network and initialize the label encoder
print("[INFO] loading network...")
model = VGG16(weights="imagenet", include_top=False)
le = None

# loop over the data splits
for split in (config.TRAIN, config.TEST, config.VAL):
    # grab all image paths in the current split
    print("[INFO] processing '{} split'...".format(split))
    p = os.path.sep.join([config.BASE_PATH, split])
    imagePaths = list(paths.list_images(p))
    # randomly shuffle the image paths and then extract the class
    # labels from the file paths
    random.shuffle(imagePaths)
    labels = [p.split(os.path.sep)[-2] for p in imagePaths]

    # if the label encoder is None, create it
    if le is None:
        le = LabelEncoder()
        le.fit(labels)

    # open the output CSV file for writing
    csvPath = os.path.sep.join([config.BASE_CSV_PATH,"{}.csv".format(split)])
    csv = open(csvPath, "w")

    # loop over the images in batches
    for (b, i) in enumerate(range(0, len(imagePaths), config.BATCH_SIZE)):
        # extract the batch of images and labels, then initialize the
        # list of actual images that will be passed through the network
        # for feature extraction
        print("[INFO] processing batch {}/{}".format(b + 1,int(np.ceil(len(imagePaths) / float(config.BATCH_SIZE)))))
        batchPaths = imagePaths[i:i + config.BATCH_SIZE]
        batchLabels = le.transform(labels[i:i + config.BATCH_SIZE])
        batchImages = []

        # loop over the images and labels in the current batch
        for imagePath in batchPaths:
            # load the input image using the Keras helper utility
            # while ensuring the image is resized to 224x224 pixels
            image = load_img(imagePath, target_size=(224, 224))
            image = img_to_array(image)

            # preprocess the image by (1) expanding the dimensions and
            # (2) subtracting the mean RGB pixel intensity from the
            # ImageNet dataset
            image = np.expand_dims(image, axis=0)
            image = preprocess_input(image)

            # add the image to the batch
            batchImages.append(image)

# pass the images through the network and use the outputs as
# our actual features, then reshape the features into a
        # flattened volume
        batchImages = np.vstack(batchImages)   # making the list into an array
        features = model.predict(batchImages, batch_size=config.BATCH_SIZE)
        features = features.reshape((features.shape[0], 7 * 7 * 512))
        print(features.shape)

        # loop over the class labels and extracted features
        for (label, vec) in zip(batchLabels, features):
            # construct a row that exists of the class label and
            # extracted features
            vec = ",".join([str(v) for v in vec])
            csv.write("{},{}\n".format(label, vec))

    # close the CSV file
    csv.close()

# serialize the label encoder to disk
f = open(config.LE_PATH, "wb")
f.write(pickle.dumps(le))
f.close()
# Out:
# [INFO] loading network...
# [INFO] processing 'training split'...
# [INFO] processing batch 1/94
# (32, 25088)
# [INFO] processing batch 2/94
# (32, 25088)
# [INFO] processing batch 3/94
# (32, 25088)
# [INFO] processing batch 4/94
# (32, 25088)
# [INFO] processing batch 5/94
# (32, 25088)
# [INFO] processing batch 6/94
# (32, 25088)
# [INFO] processing batch 7/94
# (32, 25088)
# [INFO] processing batch 8/94
# (32, 25088)
# [INFO] processing batch 9/94
# (32, 25088)
# [INFO] processing batch 10/94
# (32, 25088)
# [INFO] processing batch 11/94
# (32, 25088)
# [INFO] processing batch 12/94
# (32, 25088)
# [INFO] processing batch 13/94
# (32, 25088)
# [INFO] processing batch 14/94
# (32, 25088)
# [INFO] processing batch 15/94
# (32, 25088)
# [INFO] processing batch 16/94
# (32, 25088)
# [INFO] processing batch 17/94
# (32, 25088)
# [INFO] processing batch 18/94
# (32, 25088)
# [INFO] processing batch 19/94
# (32, 25088)
# [INFO] processing batch 20/94
# (32, 25088)
# [INFO] processing batch 21/94
# (32, 25088)
# [INFO] processing batch 22/94
# (32, 25088)
# [INFO] processing batch 23/94
# (32, 25088)
# [INFO] processing batch 24/94
# (32, 25088)
# [INFO] processing batch 25/94
# (32, 25088)
# [INFO] processing batch 26/94
# (32, 25088)
# [INFO] processing batch 27/94
# (32, 25088)
# [INFO] processing batch 28/94
# (32, 25088)
# [INFO] processing batch 29/94
# (32, 25088)
# [INFO] processing batch 30/94
# (32, 25088)
# [INFO] processing batch 31/94
# (32, 25088)
# [INFO] processing batch 32/94
# (32, 25088)
# [INFO] processing batch 33/94
# (32, 25088)
# [INFO] processing batch 34/94
# (32, 25088)
# [INFO] processing batch 35/94
# (32, 25088)
# [INFO] processing batch 36/94
# (32, 25088)
# [INFO] processing batch 37/94
# (32, 25088)
# [INFO] processing batch 38/94
# (32, 25088)
# [INFO] processing batch 39/94
# (32, 25088)
# [INFO] processing batch 40/94
# (32, 25088)
# [INFO] processing batch 41/94
# (32, 25088)
# [INFO] processing batch 42/94
# (32, 25088)
# [INFO] processing batch 43/94
# (32, 25088)
# [INFO] processing batch 44/94
# (32, 25088)
# [INFO] processing batch 45/94
# (32, 25088)
# [INFO] processing batch 46/94
# (32, 25088)
# [INFO] processing batch 47/94
# (32, 25088)
# [INFO] processing batch 48/94
# (32, 25088)
# [INFO] processing batch 49/94
# (32, 25088)
# [INFO] processing batch 50/94
# (32, 25088)
# [INFO] processing batch 51/94
# (32, 25088)
# [INFO] processing batch 52/94
# (32, 25088)
# [INFO] processing batch 53/94
# (32, 25088)
# [INFO] processing batch 54/94
# (32, 25088)
# [INFO] processing batch 55/94
# (32, 25088)
# [INFO] processing batch 56/94
# (32, 25088)
# [INFO] processing batch 57/94
# (32, 25088)
# [INFO] processing batch 58/94
# (32, 25088)
# [INFO] processing batch 59/94
# (32, 25088)
# [INFO] processing batch 60/94
# (32, 25088)
# [INFO] processing batch 61/94
# (32, 25088)
# [INFO] processing batch 62/94
# (32, 25088)
# [INFO] processing batch 63/94
# (32, 25088)
# [INFO] processing batch 64/94
# (32, 25088)
# [INFO] processing batch 65/94
# (32, 25088)
# [INFO] processing batch 66/94
# (32, 25088)
# [INFO] processing batch 67/94
# (32, 25088)
# [INFO] processing batch 68/94
# (32, 25088)
# [INFO] processing batch 69/94
# (32, 25088)
# [INFO] processing batch 70/94
# (32, 25088)
# [INFO] processing batch 71/94
# (32, 25088)
# [INFO] processing batch 72/94
# (32, 25088)
# [INFO] processing batch 73/94
# (32, 25088)
# [INFO] processing batch 74/94
# (32, 25088)
# [INFO] processing batch 75/94
# (32, 25088)
# [INFO] processing batch 76/94
# (32, 25088)
# [INFO] processing batch 77/94
# (32, 25088)
# [INFO] processing batch 78/94
# (32, 25088)
# [INFO] processing batch 79/94
# (32, 25088)
# [INFO] processing batch 80/94
# (32, 25088)
# [INFO] processing batch 81/94
# (32, 25088)
# [INFO] processing batch 82/94
# (32, 25088)
# [INFO] processing batch 83/94
# (32, 25088)
# [INFO] processing batch 84/94
# (32, 25088)
# [INFO] processing batch 85/94
# (32, 25088)
# [INFO] processing batch 86/94
# (32, 25088)
# [INFO] processing batch 87/94
# (32, 25088)
# [INFO] processing batch 88/94
# (32, 25088)
# [INFO] processing batch 89/94
# (32, 25088)
# [INFO] processing batch 90/94
# (32, 25088)
# [INFO] processing batch 91/94
# (32, 25088)
# [INFO] processing batch 92/94
# (32, 25088)
# [INFO] processing batch 93/94
# (32, 25088)
# [INFO] processing batch 94/94
# (24, 25088)
# [INFO] processing 'evaluation split'...
# [INFO] processing batch 1/32
# (32, 25088)
# [INFO] processing batch 2/32
# (32, 25088)
# [INFO] processing batch 3/32
# (32, 25088)
# [INFO] processing batch 4/32
# (32, 25088)
# [INFO] processing batch 5/32
# (32, 25088)
# [INFO] processing batch 6/32
# (32, 25088)
# [INFO] processing batch 7/32
# (32, 25088)
# [INFO] processing batch 8/32
# (32, 25088)
# [INFO] processing batch 9/32
# (32, 25088)
# [INFO] processing batch 10/32
# (32, 25088)
# [INFO] processing batch 11/32
# (32, 25088)
# [INFO] processing batch 12/32
# (32, 25088)
# [INFO] processing batch 13/32
# (32, 25088)
# [INFO] processing batch 14/32
# (32, 25088)
# [INFO] processing batch 15/32
# (32, 25088)
# [INFO] processing batch 16/32
# (32, 25088)
# [INFO] processing batch 17/32
# (32, 25088)
# [INFO] processing batch 18/32
# (32, 25088)
# [INFO] processing batch 19/32
# (32, 25088)
# [INFO] processing batch 20/32
# (32, 25088)
# [INFO] processing batch 21/32
# (32, 25088)
# [INFO] processing batch 22/32
# (32, 25088)
# [INFO] processing batch 23/32
# (32, 25088)
# [INFO] processing batch 24/32
# (32, 25088)
# [INFO] processing batch 25/32
# (32, 25088)
# [INFO] processing batch 26/32
# (32, 25088)
# [INFO] processing batch 27/32
# (32, 25088)
# [INFO] processing batch 28/32
# (32, 25088)
# [INFO] processing batch 29/32
# (32, 25088)
# [INFO] processing batch 30/32
# (32, 25088)
# [INFO] processing batch 31/32
# (32, 25088)
# [INFO] processing batch 32/32
# (8, 25088)
# [INFO] processing 'validation split'...
# [INFO] processing batch 1/32
# (32, 25088)
# [INFO] processing batch 2/32
# (32, 25088)
# [INFO] processing batch 3/32
# (32, 25088)
# [INFO] processing batch 4/32
# (32, 25088)
# [INFO] processing batch 5/32
# (32, 25088)
# [INFO] processing batch 6/32
# (32, 25088)
# [INFO] processing batch 7/32
# (32, 25088)
# [INFO] processing batch 8/32
# (32, 25088)
# [INFO] processing batch 9/32
# (32, 25088)
# [INFO] processing batch 10/32
# (32, 25088)
# [INFO] processing batch 11/32
# (32, 25088)
# [INFO] processing batch 12/32
# (32, 25088)
# [INFO] processing batch 13/32
# (32, 25088)
# [INFO] processing batch 14/32
# (32, 25088)
# [INFO] processing batch 15/32
# (32, 25088)
# [INFO] processing batch 16/32
# (32, 25088)
# [INFO] processing batch 17/32
# (32, 25088)
# [INFO] processing batch 18/32
# (32, 25088)
# [INFO] processing batch 19/32
# (32, 25088)
# [INFO] processing batch 20/32
# (32, 25088)
# [INFO] processing batch 21/32
# (32, 25088)
# [INFO] processing batch 22/32
# (32, 25088)
# [INFO] processing batch 23/32
# (32, 25088)
# [INFO] processing batch 24/32
# (32, 25088)
# [INFO] processing batch 25/32
# (32, 25088)
# [INFO] processing batch 26/32
# (32, 25088)
# [INFO] processing batch 27/32
# (32, 25088)
# [INFO] processing batch 28/32
# (32, 25088)
# [INFO] processing batch 29/32
# (32, 25088)
# [INFO] processing batch 30/32
# (32, 25088)
# [INFO] processing batch 31/32
# (32, 25088)
# [INFO] processing batch 32/32
# (8, 25088)

# %%
# import the necessary packages
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from pyimagesearch import config
import numpy as np
import pickle
import os

def load_data_split(splitPath):
    # initialize the data and labels
    data = []
    labels = []

    # loop over the rows in the data split file
    for row in open(splitPath):
        # extract the class label and features from the row
        row = row.strip().split(",")
        label = row[0]
        features = np.array(row[1:], dtype="float")

        # update the data and label lists
        data.append(features)
        labels.append(label)

    # convert the data and labels to NumPy arrays
    data = np.array(data)
    labels = np.array(labels)

    # return a tuple of the data and labels
    return (data, labels)

# derive the paths to the training and testing CSV files
trainingPath = os.path.sep.join([config.BASE_CSV_PATH,"{}.csv".format(config.TRAIN)])
testingPath = os.path.sep.join([config.BASE_CSV_PATH,"{}.csv".format(config.TEST)])

# load the data from disk
print("[INFO] loading data...")
(trainX, trainY) = load_data_split(trainingPath)
(testX, testY) = load_data_split(testingPath)

# load the label encoder from disk
#le = pickle.loads(open(config.LE_PATH, "rb").read())

# train the model
print("[INFO] training model...")
model = LogisticRegression(solver="lbfgs", multi_class="auto",max_iter=150)
#lbfgs is used for regularisation
model.fit(trainX, trainY)

# evaluate the model
print("[INFO] evaluating...")
preds = model.predict(testX)
print(classification_report(testY, preds,target_names=le.classes_))

# serialize the model to disk
print("[INFO] saving model...")
f = open(config.MODEL_PATH, "wb")
f.write(pickle.dumps(model))
f.close()
# Out:
# [INFO] loading data...
# [INFO] training model...
# [INFO] evaluating...
#               precision    recall  f1-score   support
#
#         food       0.99      0.98      0.98       500
#     non_food       0.98      0.99      0.99       500
#
#     accuracy                           0.98      1000
#    macro avg       0.99      0.98      0.98      1000
# weighted avg       0.99      0.98      0.98      1000
#
# [INFO] saving model...
